# %%
from sklearn.model_selection import train_test_split
from sklearn import tree   
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
import pandas as pd 
from sklearn.ensemble import RandomForestClassifier

import graphviz

data= pd.read_csv('titanic-passengers.csv',delimiter=";")


#remplacer les valeurs manquantes par la moyenne
data['Age'].fillna(data['Age'].mean(),inplace=True)
#remplacer les valeurs manquantes par la valeur la plus frequente 
data['Embarked'].fillna('S',inplace=True)
data['Cabin'].fillna('B96',inplace=True)
survi={'Survived':{'Yes':1,'No':0}}
data.replace(survi,inplace=True)
sex={'Sex':{'male':1,'female':0}}
data.replace(sex,inplace=True)
bark={'Embarked':{'S':1,'C':2,'Q':3}}
data.replace(bark,inplace=True)

#features extraction
x=data.drop(["Survived", "Name", "Cabin", "Ticket", "Embarked"], axis=1)
y= data["Survived"]
#splitting data
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.20,random_state=10)

#applying tree algorithm
clt = tree.DecisionTreeClassifier(criterion = "gini", splitter = 'random', max_leaf_nodes = 10, min_samples_leaf = 5, max_depth= 5)
clt.fit(x_train, y_train)   #fitting our model
y_pred=clt.predict(x_test)   # evaluating our model
print("score:{}".format(accuracy_score(y_test, y_pred)))

dot_data = tree.export_graphviz(clt,out_file=None)
graph = graphviz.Source(dot_data)
graph.render("data")
graph
# Out:
# score:0.7932960893854749

# %%
#remplacer les valeurs manquantes par la moyenne
data['Age'].fillna(data['Age'].mean(),inplace=True)
#remplacer les valeurs manquantes par la valeur la plus frequente 
data['Embarked'].fillna('S',inplace=True)
data['Cabin'].fillna('B96',inplace=True)
survi={'Survived':{'Yes':1,'No':0}}
data.replace(survi,inplace=True)
sex={'Sex':{'male':1,'female':0}}
data.replace(sex,inplace=True)
bark={'Embarked':{'S':1,'C':2,'Q':3}}
data.replace(bark,inplace=True)

#features extraction
x=data.drop(["Survived", "Name", "Cabin", "Ticket", "Embarked","PassengerId","Parch"], axis=1)
y= data["Survived"]
#splitting data
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.20,random_state=10)

#applying tree algorithm
clt = tree.DecisionTreeClassifier(criterion = "gini", splitter = 'random', max_leaf_nodes = 10, min_samples_leaf = 5, max_depth= 5)

clt.fit(x_train, y_train)   #fitting our model
y_pred=clt.predict(x_test)   # evaluating our model
print("score:{}".format(accuracy_score(y_test, y_pred)))

dot_data = tree.export_graphviz(clt,out_file=None)
graph = graphviz.Source(dot_data)
graph.render("data")
graph
# Out:
# score:0.770949720670391

# %% [markdown]
# on constate qu'il y'a pas une grande diference entre les deux précision

# %%
#remplacer les valeurs manquantes par la moyenne
data['Age'].fillna(data['Age'].mean(),inplace=True)
#remplacer les valeurs manquantes par la valeur la plus frequente 
data['Embarked'].fillna('S',inplace=True)
data['Cabin'].fillna('B96',inplace=True)
survi={'Survived':{'Yes':1,'No':0}}
data.replace(survi,inplace=True)
sex={'Sex':{'male':1,'female':0}}
data.replace(sex,inplace=True)
bark={'Embarked':{'S':1,'C':2,'Q':3}}
data.replace(bark,inplace=True)

#features extraction
x=data.drop(["Survived", "Name", "Cabin", "Ticket", "Embarked","PassengerId","Parch"], axis=1)
y= data["Survived"]
#splitting data
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.20,random_state=10)

#applying tree algorithm

clt=RandomForestClassifier(n_estimators=10) 
clt.fit(x_train, y_train)   #fitting our model
y_pred=clt.predict(x_test)   # evaluating our model
print("score:{}".format(accuracy_score(y_test, y_pred)))
# Out:
# score:0.8435754189944135

# %% [markdown]
# on constate qu'il y'a plus précision que les deux autre
